# %%
# 上辺の長さ
top_edge = 10
# 下辺の長さ
bottom_edge = 20
# 高さ
height = 5
# 台形の面積を変数に代入
area_of_trapezoid = (top_edge + bottom_edge) * height / 2

# 台形の面積を出力
print(f"{area_of_trapezoid}cm²")
# Out:
# 75.0cm²
